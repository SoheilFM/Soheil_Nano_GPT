# %% [markdown]
# # Import

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# %%
# hyperparameters
batch_size = 64 # how many independent sequences will we process in parallel?
block_size = 256 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 500
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 384
n_head = 6
n_layer = 6
dropout = 0.2

torch.manual_seed(1337)

with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

#Simple Tokenizer

# Here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)

# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train & Test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# Data loader
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y


@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# Add Head ( one head of self attention )
class Head(nn.Module):
    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril',torch.tril(torch.ones(block_size, block_size)))
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k=self.key(x)
        q=self.query(x)
        #compute attention score
        wei =q @k.transpose(-2,-1) * C**-0.5 # (B,T,C) @ (B,C,T) -> (B,T,T)
        wei =wei.masked_fill(self.tril[:T, :T] == 0 , float('-inf')) # (B,T,T)
        wei =F.softmax(wei,dim=-1) # (B,T,T)
        wei = self.dropout(wei)
        # Performing Weighted Aggregation
        v=self.value(x) # (B,T,C)
        out =wei @v # (B,T,T) @ (B,T,C) -> (B,T,C)
        return out

class Block(nn.Module):
    "Transformer Block which is communication followed by computation"
    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa= MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x +  self.ffwd(self.ln2(x))
        return x

# Multiple Head of Self Attention in Parallels.
class MultiHeadAttention(nn.Module):

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self .proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)


    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out)) # Drop out and Linear Layer
        return  out
# A simple Linear Layer
class FeedForward(nn.Module):
    def __init__(self, n_embd):
        super().__init__()
        self.net= nn.Sequential(
            nn.Linear(n_embd,4 * n_embd),# Linear Layer
            nn.ReLU(), # Activation Function
            nn.Linear(4 * n_embd,n_embd), # projection Layer
            nn.Dropout(dropout) # Dropout Layer
            )
    def forward(self, x):
        return self.net(x)


# Simple Bigram Model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f= nn.LayerNorm(n_embd) # Final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x= self.blocks(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)


        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss




    def generate(self, idx, max_new_tokens):
    # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop the context if it's longer than block_size
            idx_cond = idx[:, -block_size:] # (B, min(T, block_size))
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)

# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)


for iter in range(max_iters):

    # Every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# Generate Text from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=1024)[0].tolist()))
# Out:
# step 0: train loss 4.4753, val loss 4.4709
# step 500: train loss 1.7521, val loss 1.8963
# step 1000: train loss 1.4430, val loss 1.6566
# step 1500: train loss 1.3118, val loss 1.5593
# step 2000: train loss 1.2261, val loss 1.5238
# step 2500: train loss 1.1648, val loss 1.5239
# step 3000: train loss 1.1066, val loss 1.5163
# step 3500: train loss 1.0485, val loss 1.5373
# step 4000: train loss 0.9966, val loss 1.5649
# step 4500: train loss 0.9359, val loss 1.5676
#
# Behold off him his worldship spilt:
# So, merely lady! I know the lordship,
# So sound with a fool me words in the hole,
# The which my friend of it fears high all the
# discontent. Ah, make haste, let the heir
# followers followed with fore suction.
#
# Shepherd:
# I was; never of the glorious country right!
#
# Shepherd:
# Take letters; ne'er did ear in rot an apparer's wagged,
# During flowers laughters' peace cheek-faped,
# Vilely'd in heavy likewise twice in day.
# But likewise his body to the fire,:
# A good time have a simple gone, I will not reconce but you.
#
# CATESBY:
# Yea, my cross friends, I speak it in mind of that:
# She has some days scoldly sir, cried 'Country,'
# Say to me, I'll make thee side; fond to me queen.
# So, he have seen the heart same others have lands.
# Are you made a fear: off with the gods world willies,
# Which to these please woman map with mere, that fire-rocks
# And woodly lurky frown, and aside it most neturn'd;
# With torments thou of have breathed a sleeper;
# And thy hazard hands we will no cause,
# But to beater than

# %%
# Print number of parameters
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters') # 10 m parameters
# Out:
# 10.788929 M parameters

# %%
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2048)[0].tolist()))
# Out:
# Nay, might pleasure,
# They have speciallel'd upluloused, and solicians
# Down, unless corged immortal to blood
# What I am. O concerns! I have hated thus that hand,
# Whose honesty faults, hollowed the air youth;
# Boar, necky and her,--fook and every safet;
# Pleanly many stir, whose cures of commanded,
# Now those housand these fresh instruments
# Ends me and cheek answer hath strell'd down. For his hand
# The learers walls against companient with a
# goesty forsworn.
#
# Lord:
# He stands no more.
# Was for my felly; he are glorious o'erween the east?
#
# BENVOLIO:
# I gone:
# My general is a great; to dengration
# Is not to be the lifed of mine honour come,
# Which may most confess that will have hardly act
# The recemblon ate war to him.
#
# HERBY:
# Pay, would I see, let me look to-day my wrath!
#
# SOMERSET:
#
# BAMNENORTENS:
# Do you so?
#
# BRAHAST:
#
# HERMIONE:
# It would you swear to die, and him right from hence;
# I have from your brother's eyes shall be beheld;
# A row or nature interpression to parcent;
# The sight o' stranger in ears up offine,
# With the whip opesticious woe have been camels unwork!
# Would I weigh'd to cut  or four marks. Hark!
# Were I so for that issues famously to make?
# We pray, my circumpaning cohes? As I wert not bites?
#
# FLORIZEL:
# Yes, you think we well think none of me.
#
# FLORIZEL:
# Unless your great rule leisure
# As if he companion to know the encounter of a purse.
# But, let us breath, my loroughly ust: for,
# Atoner a benefit o' their own.
#
# LEONTES:
# Do slander what is comes star tith our divines;
# And we conver'd to this field-balanes
# Winning it observer: here were my now toil
# I am discover'd; and I, in mine that drops
# Doth confess my sisterhonour. May I, be
# Deservent the Margaret's scerning? 'tis son
# To know our grace,--
# Whom is smile in the heart and the court'sy,
# Cilduck me toward Cominius.
#
# COMINIUS:
# He crise true,
# As on the court first, as please yous whorn armed
# We two other?
#
# CORIOLANUS:
# Where we'll breathe;
# We'll shark you.
#
# SICINIUS:
# I hear implore:
# He means me possibibling to my wife.
#
# BRUTUS:
# Even with your honour's cannel great love.
# I

# %%
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=4096)[0].tolist()))
# Out:
# Provost:
# Else your honour, sir.
#
# DUKE VINCENTIO:
# This behalf that hath the mattest this coher enough.
#
# Provost:
# As fello's like envious, soones,
# A blow rough and virtuous pantiately,
# Which he thinks he louds do cure fhich her picks;
# Pray God comfort it, to the ravenly scarce.
# Farewell, this only land was like ungentleman
# To goest the respect and to his bloody balone,
# Not how two cause, for twent of recomfond
# Meltibe, thus free. Cleave let us himself.
#
# SICINIUS:
# He's doth
# Mewared the people:
# Do you heel; I hear me speak:
# even sin, my heart is proud.
# The people malice were I undertake a tabted so;
# Your speedy clear did mistruck in the appeal,
# Suspicion story, with me in me and pacting?
#
# VOLUMNIA:
# Why, sir, be but a fool.
#
# CORIOLANUS:
# No.
#
# MENENIUS:
# How! I that, sir, to get?
#
# CORIOLANUS:
# Your sweet speech!
#
# MENENIUS:
# I speak not time.
#
# SICINIUS:
# I will give him of him glim convey.
#
# CORIOLANUS:
# It may but for you. The Caius care nor home,
# Sir, for most raighness more at vitae: we give the service
# Takes free my here.
#
# COMINIUS:
# On hearing,
# Must that way against you.
#
# SICINIUS:
# We were,
# Cut not your zorthy slock, to the prince's apparel in the crown,
# With smilipt suffer'd us woons. Can't he loves
# Proceeders so hearts the gods sire; hearing
# Shall be of that justs, firth comfort.
# I am good to make circlosity: you're now
# Some man.
#
# ISABELLA:
# Why, so, 'tis time were, that you'ld lose.
#
# LUCIO:
# Third is returner our thief,
# Do you pass me; and perpetuity.
#
# LUCIO:
#
# ANGELO:
# I like in not instance upon to lough the world;
# There is come to know on me: I must not
# To like an if whose justice of men at every mont.
#
# LUCIO:
#
# ISABELLA:
# I have heard, the prizens apace of a sneelina
# new commastering an ill time that pronouncal:
# Why, ho!
# Not the gods this day, now, not so.
# This fellow do him flour? let himself.
# I mark, from fort the worldliers fearful vows:
# Preventil to this lies
# Were join'd, with the own tongue streets but
# The wrinkled'st to't with well? Edst thou, Lord thou honesty
# Theremble success a name of death?
#
# VOLUMNIA:
# Come, I must I be gone?
#
# BENVOLIO:
# What, no more, be so blown as where he delivers as slaves,
# Will have the blem made himself.
# Latewed more cast me, Cominius: this is most
# My trick mad it formity; you might leaves in me
# here with whom I am in pound, and in justice
# Holining common.
#
# SICINIUS:
# Come you Corioli?
#
# MENENIUS:
# By noting, lord with any of foundature
# What you deforcemency may here be at wont,
# What false you have mutureral to-noble on?
# For an aching scolding word, the
# know that like you a child man's, they
# advocate heart clear me in me.
#
# SICINIUS:
# Faith, we without with you.
#
# CORIOLANUS:
# Fully.
#
# SICINIUS:
# How!
#
# MENENIUS:
# Will it please you home?
#
# COMINIUS:
# Ay, and buy the fit. Cominius.
#
# MARCIUS:
# At home the people's offence should be put
# More than known against his eye, which discontence,
# It honour ourself her supicious: the fun and the
# worst crutckets frown me.
#
# MENENIUS:
# That,'tis the world so to seldom upon hit.
# Seerce to Lucestion we are shall assurer
# As thick so use to afford the heated of this seat,
# And know't with those business to dwel
# Enforces the law the council: hours,
# There was spur, and smooth too?
#
# MENENIUS:
# Comme, we'll tell my father;
# There sighs,
# Whom for offence that hours gives beholds
# So so hot flight as supplied
# Shedter craves for like all: all of me
# Till we gaze behind; instructed to one Tybalts, my cantage
# Counseless is rott with the white-groan alies
# Where comes so unsubpride. Come, peace!
#
# SICINIUS:
# Bawnell Soft!
#
# COMINIUS:
# All this doubt within his honour downring in mouths,
# Your cleation, not his, nothing trembling;
# For, like the daughter with all place.
#
# MENENIUS:
# So,'tis hell.
#
# CORIOLANUS:
# One shoulder,
# As it be so, she is cherly in stock ones;
# Come who on the sea baseness
# Of a smanner.
#
# CORIOLANUS:
# Were he made bring his time
# To some offence.
#
# Second Conspirator:
# With thee, old Coriolanus:
# False Corioli andirectly gods, to make the
# Worth their more trembles: thou art i' the story
# And waft with Rome, think so distable
# With told their meeks and a former against world,
# That thou seest-b

# %%
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=8192)[0].tolist()))
# Out:
# Errone See-wild, by the enemy oath
# Would never but by unsatural traitors was
# Of what way, which to say put it on the white point,
# And with the stropp'd lap, wept the great fineld.
# O Thomas reason will I defend hell with meer,
# And disturb late of most love at ittere;
# Holdly to the wife reck
# By death of necessariege not lost may you commit
# That should be most calument?
#
# EMILLO:
# To prize me here, Clowdericlio.
#
# LEONTES:
# I doubt with him the cause.
#
# BENVOLIO:
# O, that with us?
#
# MERCUTIO:
# What else?
#
# Nurse:
# Ay, an I were not band. 'Where honour of a kind of importine
# That sweet you gives me present enough.
#
# MERCUTIO:
# By repeal: the strength here is mine strangel in you: say,
# You are most contented he was not:
# You stand certains he is justs,
# If he had said out Cominius.'
#
# BENVOLIO:
# If well, sir, my wisdom wits not:
# Ay, as he entains up yet.
#
# METER:
# For 'tis too true.
#
# BENVOLIO:
# Wrath, debt in his fine.
#
# Provost:
# Who is the coldient unhusband,
# The absellable himself was where, and
# I'll help without use him world,--
#
# ESCALUS:
# Say, I know no side?
#
# ABHORSAND:
# Why?
#
# DUCHESS OF CARLISLO:
# Stoop, Clifford! your soul: dost thou show
# As the state as is Lord Juliet as I am bounces'.
#
# DUKE VINCENTIO:
# Why, other, bondel? faith, did show the like heart?
#
# Provost:
# Who singless you? o'tre then judged by Angelo?
#
# DUKE VINCENCENTIO:
# Is royal renowned in his opinion,
# Because to be come in mine mocked with him,
# And with me some merry at his cornion.
#
# BENVOLIO:
# It cannot will show him in so customage:
# All too, must he shall not now weep.
#
# ROMEO:
# I'll walk before thee to beh friendly.
#
# FRIAR LAURENCE:
# Well are not found to be tickle'd with violage.
# See, how those wonderers against the sha.
#
# MERCUTIO:
# You have consul! would I conventure with her,
# Axaway with me all these woes would apon!
# I know not that, the bastardy, both the queen gangers
# That hath the dissent knaves o' the devicions so
# clut'st some pinion of fear, remove them!
# Here is mone and on himself,
# Dismitted events those ready with honour so?
# Or thou hast name to her comfort? Did I lect thee?
#
# DUCHESS OF YORK:
# What is that?
#
# Messenger:
# No more, sir?
#
# DUCHESS OF YORK:
# Here is the concest, that with my John,
# And all his led son, if thou coming,
# Let'st upon me.
# He is content: for God's great answer to
# Succester-bone, as it let me fearful and nature
# For this companion!
#
# VOLUMNIA:
# Sovereign and goodness ago.
#
# CORIOLANUS:
#
# VOLUMNIA:
# There is too strew'd,
# Which thou on thist to'crow'st own. Preparer, let knock,
# I'll do him; marry, if you'll not redified
# For him plife; shall stand, as you have power
# As cause told upon this fair mast on,
# I have bey'd for't; my word, as I do,
# Wethall no mark my free burthen'd and what mere,
# That was your honour's natictor?
#
# FLOUFESTZER:
# Stay, your opinion and yours;
# Which, master, sir, he doth not tell
# The bsaring of occurce that which hast
# But you have shame like madis, with calaiming
# With winds and smile threary. Come, let's go in;
# For common me to better hot to him
# Wreckets he with ones.
# Sometimes! who to the matter?
# Afore use the fifty time to seem the others.
# There lies offence for us? No, no, thou seest it I am.
#
# CATESBY:
# If thou delevention on of so tealies
# Darlies our coat, wounds left thyself,
# I condemn and minest words conference.
#
# KING RICHARD II:
# You shall be recovertary with the father seas;
# My sons forth and with the rest,
# Grown fair QUEest reinful seement.
#
# KING RICHARD II:
# Withink you, masters: what he do?
#
# DUCHESS OF YORK:
# Yet thou shouldst, my lord; and I protive no living
# To saying men must persuade my will bring imine
# A banish'd tongue for betched mocks might;
# Gentlemen with the criest of the ring.
#
# HASTINGS:
# What do you of your plaguest love?
#
# RICHMONTIO:
# Saw't you, I am.
#
# LADY CAPULET:
# A merry,
# Beguile and by drunken from her swear;
# Not our life is he in start.
#
# HENRY BOLINGBROKE:
# Pale it be, sirrah, but in revenge
# By dangerous stranger let's imagine.
#
# HERMIONE:
# I will not have an ended well,
# Such a brother,
# But being sent upon reverence and grow.
#
# HERMIONE:
# But, my good wiy will make soul:
# The duke is our main and years for a weak.
# Pray, come, let us revengeful master lights
# Shall buride the proper for your appetite
# And mock'd to my poor hope; on that, go with espect'd
# The will look'd to a humoring store?
#
# ESCALUS:
# Spirt, I mock that I mean for that:
# To use I desire to safe thy dam. As thou is excellent,
# Harbitrance lows more in vortuous quench:
# So many so much in courtiers,
# Without confession and wildly sense;
# I rise your love from your son service are all just,
# See one forth another hand one can addissain.
# Unfit by a pupil calamity;
# His alamity to the good host,
# Hath over been me in his own conjure,
# As he is in the hath oaths comicate
# The whis offences doth confound to use--
# I'ld his discolour'd beatences: the pointed
# He, since: the time most pleasure of
# Consible the bable--
# Thick on my grief best extreme, say at be
# Most preparaporous! So villain! Good folish, I vow
# More certain a suit of bracherous!
#
# CATESBY:
# O younes!
#
# GRUMION:
# Then, fool!
#
# GREMIO:
# This time should be:
# As brin in her bestleven, as altoger'd all
# A' one him than with the malice of him:
# A name opinion, and stand in the sight.
# Thoughts are too widow'd and with clamorly please
# To base with the stars.
#
# PETRUCHIO:
# Take hence for him;
# And you shall talk the orphan's to seal'd;
# So, reverend at him your potsers.
# Thirs, then, sir, like unstand blood, much soul
# When I peer'd, let me have more like my breasts;
# Shame I interchange that unto my son,
# The slew stoop'd after scolding heavily
# But to sea light with terny sevents.
# Go you to any another husband!
# I never know your grace, most free bless.
#
# QUEEN ELIZABETH:
# So so we offend and of the prince young staves,
# Which obey to be sworn some of my feeding,
# As hymoking grave here in mine arms new wind,
# With such fallen virtuous nature ones,
# And send the stone: the view of men
# The height on't insully the mother beetle;
# And bring which ut
# Twelve to like us off soon their attir wrong'd;
# And yet but up our sights friends.
#
# Second Keeper:
# Give me itself; and without Mariana
# S' merit is as an as your.
#
# KING RICHARD II:
# Belike to me, thou Marciusanes!
#
# SURRESS OVERSIO:
# Alas, the Volsces are so greatly: they say 'Tis sures,
# As we lies past within.
#
# HORTENSIO:
# Ma Jove' lord, believe you.
#
# HERMIONES:
# I will tell you set it so that act carflesh
# you shall have more at feeding: come your blocks,
# and-goad lead you have with a taster state,
# so like graciously saw starves may most aught
#  home.
#
# TRANIO:
# No.
#
# LUCIO:
# Thin is your worship, my report; not
# so not as yet as my poor professes with much behalf
# thee: every time will suy heart;
# That would not burn like me, lords, let's continue.
#
# LUCENTIO:
# Come, come, good Claudio!
#
# CLAUDIO:
# Not to dnow, sir.
#
# CLAUDIO:
# Thou shalt ask yours, whence as a Cluffolk.
#
# LUCIO:
# Friar, take not and unduty: all of it
# meet Rutlas and truth more did stand, I speak than,
# Where I for this fell effect blows to-morrow's royal dut,
# But nothing stern, by the bottle; make course
# Propousies, hath he lived lies to leads:
# So by money-seeking dread, that they think not so stop.
# Alone, to my gift; stand on to me this:
# Booth art future, as I obtate here well accome
# To smile with a castar's wit:
# Tell me to you are the prince, alone.
#
# CAMILLO:
# Go thou,
# Along so with blarges; and yet is firit most pleasing:
# awaking, and if reverend me occurse the marketh king,
# Nothing shall not beat our charges man. Sight? and
# Say, counst thou hark, knock, being of honour,
# I would, which of you might sing it my counsel:
# Like to mirth, poor misely to an end.
#  Clown: good think here, I may constain at him
# Behow the greater city.
#
# First Citizen:
# Belike, it is: if you do depar you, good father Stanley!
#
# CORIOLANUS:
# Most minutrus,
# You have but not bear foul apprones;
# Now your knowledges to be true.
#
# CORIOLANUS:
# Mother, I appointed
# In that shad love shadows of.
#
# SICINIUS:
# So thou:
# There's tying,
# Unless you?
#
# Volst Citizen:
# As every prithen's doubt the Volsces
# Undeed Coriolanus, but his hearted should, having once
# Sith in a here--our sheared more conjoctune,
# I thought a booking with a heavenry;
# Abbour with him, with his miscance
# One in that he beseech put himself;
# Sowice come cantain:

# %%
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=16384)[0].tolist()))
# Out:
# Bleshop with, and soon any other.
# A bugger-clied change mother than you'll fight;
# Perhaps it in my birth, and amends
# But to hear they your liberty; the one, of this pable,
# And gallops the once, how rules he hath done,
# changed his bred to use; but nature's blows not
# Conceiving the garden apothet in all,
# Which ease become all, say and more do half;
# Each wem to Paulina.
#
# CAMILLO:
# Holy father.
#
# CARDINAL:
# Pray, be you.
#
# BARNARDINE:
# After, Romeo!
# I would you have leverd have solely securcy:
# When the duke is sleep with me having discharge.
#
# ARCHIDARUS:
# And officerse: only now his mother.
#
# MENENIUS:
# Then is my poor povet. I think I wis. There is doom of!
#
# SICINIUS:
# A second tribune of me:
# You and for no antoted his business' highness hand
# Bots and miseries them there. Prive within,
# You weare not: within testributions, prignabl,
# Hollest to holish with summers! Joint, command cunning
# So shunnectly; though desire my depart, this
# imprison and a pinemy, but only too none,
# but in that time-maw's mother, would not let
# The peopleasure of us. Sweet goving
# Makes sweet Trespal, do in our father, we mean to inconstant
# The graced of this virtue worm, which else
# Break or none of us: off our son
# Dreams with proud; obleness minded wer scolds
# With stretch'd weigh, cleanly ruin'd against the wind!
# Dogs,
# More miShop, mine instruct; for my fair gestand garden
# So like friend, as wacking him: this most rust,
# I took you in assistering of my dreams a thores;
# Spring for Romeo's before.' Wind 'twas crimator
# That is histook me but blewd
# To come to minutes, or I'll conth him.
#
# First Cupitol.
#
# AUFIDIUS:
# Paler:
# Women for my honour in this enemy?
#
# Third Conigman:
# I' the cold found with her love warrage than doth stone,
# I drew to in Isabel, pasted made not him,
# Nor her but likewith all this; the onding and hollow draw
# His life horour?
#
# Second Citizen:
# We are all; and thou are.
# Jesu, Signifolk!
#
# MENENIUS:
# Here's offer for circumst: may we su socians,
# You will inclinince farthest are aid; if you
# Hath shall baste your contrance: but shall be grardened
# But with a waid of winder vigate, and braving the
# should act of him.
#
# SICINIUS:
# Say, he has for much grecians,
# With tuggly counsell than already.
#
# Citizens:
# We have song: we so far use within,
# We were blind to our conscience, we shall not recorn:
# But it tnough were if the let he made was law;
# Respect him as it instruct as, we mighty
# Seemsence that you have served to hear for his.
#
# ROMEO:
# Cousin is done, ere understand you this youth.
# Wratch old my lodging stones?
#
# QUEEN MARGARET:
# How now, my Lancasters! we want thee,
# That against Him that Duke leave to seee.
#
# WARWICK:
# Oxford, Oxford! there is too not forship.
#
# HENRY BOLINGBROKE:
# What come?
#
# BISHER:
# Now, Catesby; his ismiss'd;
# All as I command his. But, you dissolver but subjects
# Show in their feast of action: we have steel'd seem,
# So soon as another in flove sainter,
# We'll answer their friends for their loves.
#
# BENORDERBURKINBURY:
# On poor convital, whose the time to are let to
# From the where; yet your so heart consented by
# Rosalines, like gates, and after three-prince
# Had wake o' the jealouse wonderipting,
# May 'twelve yet repain to a choice and resigns
# To hinst reelant from heaventure. Post the offence
# Cominius to yourself, but moe
# More at point I shall writ to Rome such down,
# How have daughters 'twill it done?
#
# PETRUCHIO:
# Holy Laurents' lady,
# By a truth to command to ditpate their coffice?
#
# GRUMIO:
# How have strats thou, boy?
#
# EMBERCUT:
# Hast thou offer'd the fliery?
#
# HORTENSIO:
# O, come, he is work, some.
#
# STANLEMNER:
# So much his own; I had it all hers: but,
# I will lose my hearts at my occupation.
#
# HORTENCE:
# Under your grace! Then who profateeds hath rure
# With DeIV:
# The walls and for this night,--may be the common's attendent
# Which necess?
#
# Third Conspitable, tributor:
# More of that robbinancy
# Is enought by, us stone words of my revolt,
# Which I do lose so blood past for Rome; who poison
# Do proof the knite tongue-to to death: you must
# Call us writ with weak an oath?
#
# BUCKINGHAM:
# Who hast the own becomes hither strength to speak?
# Every gross; spooks not to the seash?
#
# SLY:
# For aught us ready.
#
# Pardon DON:
# My lord, I do, hath spent,
# And I would allow know you have so store,
# Nail so I counterb a deal!
# Sweetly, and bloody, that know not for I would,
# The best morning than I, both should beguile in me.
# See how mnjustire laws upon this place
# And belopes dangers; for likewife
# Was the great gallan-likeley's offine?
# Look with him that who muck rejoice with him;
# And whateful I know with ribs of love,
# Would many capts a hundred sword, not with breathe
# Of Polixenes, wishing himself and flight were one
# One time-day in zzree-move tongue-belew'd flowers.
# Stars like to like a coward stock that bottlenest time
# With to the fearful hold closemers!
# And her well arm'd for hare gone? I dread up:
# The king cast is no live remembrance and his
# Mistal dead with a discarricious new direction;
# No word forges of confines, till let the reign:
# Speak not in my mind the world;
# So with sighs fair and his folly.
#
# LUrd:
# That's I kind conscience, the king:
# My master lord, more provided in her own true,
# And to draw the face may live husband;
# Spare he look'd off intercent a foot in hour,
# When not that begin with a mast very place well?
# The gods prince that opinion mcome you know
# Would not what we have vouch can despair? I will under you,
# But, not putting it witherwise than you:
# The day she is unfolly; as she you are,
# Your honour uncle. You kind when here well.
# You shall be dined, that you shall please your scurns
# To pals you know friendly, and bids let not so;
# So saying your brother's triers; and it is that strange
# My wife thrive hath spokenly.
#
# FLORIZEL:
# And so would Claudio:
# She's very! I would have spoke but foul.
#
# Shepherd:
# One doth:
# 'Tis drunk in dust-traving Tellum's coward,
# Or, if we old one drown  to be heard,
# And he doubt revenge with such a thing state,
# To make a scene simperhead at me speech.--
# She is an oad true tired to my made.
#
# Third Consciden:
# She, hath he in the kiss'd to stranger buck
# And mock'd sweetly the tract, melance and guilties
# And their souls, to that hear of a goodly heart:
# What is he in that cannot now be to keeper again;
# Both king it me to kill amen's enswer;
# And in a such weating wits a story bloss;
# Parkling slow can stight converness
# Where lawful spirits on his wife's envirtue;
# Which we like ready motive with such a virtuor
# And great odds conscienceriously towards him well,
# Sucrifully dismiss'd him minal son; gave wanted
# More than wavest the nest stable cold compouncil:
# He hath slaughter'd the sweet some soul'd and his virtuous.
#
# Nurse:
# No more, sir; the woulds be good.
#
# HERMIONE:
# That were hang such was met of flatter, the gods
# Ere idzing, no letter, for they folly meet
# Incluse they proud asily was freshered pensent of the Clarence.
# I know not whe best ruthless and walls
# With our native burthen and four courtier grave
# Heart with judgment-wear whose wide action ear,
# Allow'd awcord and lowly beggins to aught;
# But leave with boldlys of my prince's son:
# They look not at once where I may be now:
# But Tuary's arrivings sense to-morrow! what time hath
# And few specters into herward my foremans air
# And breathsomely for proof mine these world,
# Which if he is, so would become this master,
# Were bold no four person; who sore of his knee,
# My way to scold in 'The part of men day is better's.
#
# Shepherd:
# It is face brought Henry looks on it.
#
# SICINIUS:
# So, no, by: becaught my wit: I can speak before well.
# I was too trick-two law, let's fair enzontrous Lady:
# And, I pray the prince throne ere shallow to be round,
# So subtly on the mark out
# Of threach, nine doubtful, threateneds with blime?
#
# COMINIUS:
# You are here.
#
# MENENIUS:
# To this mut'sty wounds, my poor bench'd in aid
# Is an old transpore: though he loves me,
# Are bright to that modesthes crown.
#
# MARCIUS:
# The Cominius is truth, the second with a maid
# Before him; I am Romeo's man thousand on Rome
# So dangerously Pleasans a Jylat by
# To laurelentings, afoely would appear
# Join'd with lengers: your highness and accessary
# The father he more than the songer of the state
# Who you, or wife?
#
# First Offol:
# Come, lay the wrong: if he be gone
# To go the oath of my instant and hap.
#
# SICINIUS:
# Woe will.
#
# MENENIUS:
# Me no matters from A sail:
# Upon goes!
#
# CIANUS:
#
# VIRGILIA:
# Mething our unening to-morrow well.
#
# AEdnesdays:
# You?
#
# First Citizen:
# You have made my powerful,
# As, and you have brought too.
#
# Second Citizen:
# Commend me to him, or your concludes curface!
#
# First Citizen:
# The same he did with him; why, I considering to
# the silent cromes. A boon with and creaters!
#
# Servant:
# O sir, hound sir, the did mock'd my constance in his own,
# Cut of his honour in wise: the role issue
# Which was well welk estables well inlaim of their trial.
#
# Shepherd:
# Signing them our city and the wrath must behalf
# Into the false anmination. Lamiza, pronounce,
# I have a hateful piece of your threats; the fond all use
# That I in country. Against you, may never be so.
# But,
# I do beseech you in many dains
# That blind made immortal.
#
# DUKE VINCENTIO:
# So, no, my lord.
#
# LUCIO:
# Well, would your honour,
# You must better than your braver space, sir,
# You have sainted committed with me to report
# The common mutterary of an hour weak.
#
# DUKE VINCENTIO:
# Some sovery; and too tast here
# When ever yet her be the nosest childines,
# CLAUDIO:
# I lodged you well you some thing.
#
# ISABELLA:
# The sister in me,
# I see in mine changed with Tybalt,
# Who should past before, that Pompey I am: to--
#
# CLAUDIO:
# To great Pomfret:
# My lord, you till gone as lent. Beseech you,
# Better as you see how in our tribunes?
#
# CLEOMENES:
# Then, gentlemen:
# I'll all see for you show's again.
#
# LEONTES:
# If the weaky in speech will but one them;
# We should be too strike of isu.
#
# CAMILLO:
# Come, I should more,
# ISABELLA:
# I dare your honour.
#
# CAMILLO:
# KING ROMEO:
# Unless it his pleason.
#
# CAMILLO:
# As I bid like like her strangel on receives.
# Are you this Angelo?
#
# ARCHIDAMUS:
# I will abate in service, I how his grace
# In multituder, be accounterated, doubled money:
# Let's perjurn and rofit of the trade.
#
# POLIXENES:
# Stoop, my son, so soon
# That, I'll murdering them: when I am.
# Unless you, yie we and yourself.
#
# LEONTES:
# To him;
# What, I should must be so?
# Your worthier, is your fortunes so learn'd?
#
# LEONTES:
# For else shall learness carries with east!
# Forswear! Boy! O plague of women's descene,
# Melay'd my brother!
#
# PAULINA:
# A morture confidence!
#
# LEONTES:
# One that 'twould they swear with light composition
# Shall rule tears by me; where I can that marry so
# another in Lean-secute that wants shall rules where he has not
# Seturn'd: for writ for the trade of men's rit or mine
# Which have you vow'd that given frottinence, warrion!
#
# LEONTES:
# The Earl of Romeo's kind hour, in the field afford
# By Behneskolies of which your son--
# Hold the higheadest subject mad with in thee,
# Stawbed more refutal wither'd tent; against
# That the dear ringer of our grandness.
#
# GLOUCESTER:
# It is not well well.
# I hoppines like best made this honour'd,
# The sacrifice oft honorrow blews.
# Here coz, master that youthful urone in the
# noble common; they were af the knowledge,
# give Keept your treasure of tailors' way?
# Here wot? marcher our houses! Have you, Heart,
# His body for trimes bridal with thee:
# That gave un this head runcle is her was just!
# Condemn'd to me give the hoar to me a person
# With countriving supbrance! Catesby
# Would I here awhile! Happy things to the curtain?
#
# PAMPHEN:
# His news is the sword; you'ld the Capid's sak.
#
# GRUMIO:
#
# MARCIUS:
# It is a foot basta visage.
#
# SABELLA:
# Good gentlemen!
#
# MARCIUS:
# 'I'll not for terror your maje have been:
# Yet you might me return, and a man last as mask,
# You have a knocked as the wallow'd in may
# As hearts but from the midst spect wed bold.
#
# ROMEO:
# What, hast there?
#
# MARCASIUS:
# Well, my lord;
# No more weep and known; but, but I of him
# That I am in sourney's light passance; to among his
# The frozen to bear his heart that the modest moon,
# Down and all hist hearts, to know the watches!
# VIRGILIA:
# Would he be mark,
# He indeed?
#
# SICI:
# A thousan;
# Take him of to-morrow!
#
# BUCKINGHAM:
# Ay, good Catol, no more.
#
# CATESBY:
# I hopinisk and you mean,--
# Catriving the rearer with a friend
# Wole to your heart and paper in a sisterhood
# Wy oath on the inward espect will be so
# And mocking them our best or that worsly I gave?
# Edward: therefore, you may amen,
# As thoughts I burns against this wont as was not just;
# Hard-villain by force lay will pack
# Lash an already like to be private time.
# Woo, wilf it in himself? No more vanities than
# Justice can out on me, O,
# If be so by this so letter
# That know me within: ever storm; nay, as he hath seemselves
# A gentleman black about whereof you:
# Mereiner, if you new'st from dance; for this wound
# So any this time where his brone
# Do all frozen our facking; and the other nay
# Departach-bear him; bat, 'twould had lelieve
# not be the moon motives; who, his paUntinous,
# Would be consul: the gagoes opposite
# I of all encounter course and unitects:
# And, to out insay the station of,
# Which art so servant tears of ma as ever wors':
# if aught in Authority will I make my pieces!
#
# MARCIUS:
# Well, I conduct him, when I shall her believed
# The people is slander ear.
#
# All Conspier:
# You did resolve this cold.
#
# CORIOLANUS:
# You tempt me pass'd with dis comits word
# Shall survey town and be grief. Uadest you,
# Lodg take on my tribunes fast that run.
#
# SICINALUS:
# We'll know your great prepared in free was so fish?
# But, let me what is this
# That fault to repent him jest.
#
# ANGELO:
# What's the Cutizen?
#
# ISABELLA:
# I am lie, not Romeo, the shadam well once.
# Drumpen'd, there he would lie spoilt this matter?
# This is tender that the day's speech:
# Kath, I heart-like such eloquon'd by his cheeks
# With spray infable and spread with o'er-there;
# For then where we may slain out.
# He comes her fawake, a thousand we pass;
# By and good Menenius 'I to bore him thought,
# Which triuty is a garden finist. Thou weep'st,
# Where we were felded and driven in neess,
# I show would not ruin.
#
# AUFIDIUS:
# O,'tis true.
#
# CORIOLANUS:
# Let go:
# Your trink will. Do you go,
# And ampoy'd the grave gods must not the lion.
#
# CORIOLANUS:
# Romeo, at you see, your grave prison'd well:
# Come you low to-morrow;
# Tell you on him, that can be seen, and despair
# So find his person's butcherites: my sweet eye
# Of what a man I am,
# Even husband, and now to your nature.
#
# MENENIUS:
# Good the grace's spirit, with the consuct of a male;
# Wrapperite, nent to bad; for, if any likelihes
# Which none lies affects motion store. Let me,
# Came her honour to?
# Or, of our dost of her fanstere,
# Who should show could ulorn out of carrect:
# Sail ague, for ever I cannot from nist;
# Till our mortal social or very rats
# Such sea,  should more at to that day,
# The mistress heart, stabb'd with wind and motion
# Who lands there is no bunest fear.
# Farewell, far you all,
# As for mild I fighter by inclenness.
#
# KING RICHARD:
# Sweet wite you fly and new-trink inged sleep souls
# It with my golden compliment to Buckingham,
# My gracious daughter'd will now again.
#
# BLUNT:
# Menenius not, were consul, whence did to speak,
# Nor face of commanding swars in distors' lane;
# There was word aught about, wherewelcome from the malapesty
# And morrel in this common convectable worse,
# When cannot breathed them; though a tymelence of death,--
# Cousin on our Mancientry's tains of his bost,
# As man, as the last is lost.
#
# SICINIUS:
# Come, come Cominius, and certain; some Roman's.
#
# BRUTUS:
# We'll not Marcius:
# A so? 'tis Corioli?
#
# COMINIUS:
# 'Twas Or ell-mark'd time there, when has so.
#
# CORIOLANUS:
# With the two offence; hour,
# Not Rome, you'ld previse you.
#
# CORIOLAUMENES:
# My lord, good brother,
# Say go must news.
#
# CORIOLANUS:
# Ay, he's commoner.
#
# SICINIUS:
# Say' too door.
#
# CORIOLANUS:
# No fuler,
# Word into our poor in hazard: you of much
# Having.
#
# BRUTUS:
# I would we peer, come inhence, whereon.
#
# CORIOLANUS:
# I do but conduct that I shall resolve fought,
# Without what the grief wars so unavour'd but either,
# Which, we preverended begger, the hanging.
#
# SICIUS:
# He sentence the Volsces mark;
# Where in the Vernicit of his hatred to hear
# Juliets ends; nor to his altowes.
#
# ROMEO:
# Go save, to walk in heart; but we'll tell her heaven
# Are half told you chang into withem?
#
# BENVOLIO:
# Montaliy, they protest then lay of us
# Before you and visitions, whom to the point, could
# But post of his. Camillo commands
# Counsell'd you?
#
# BENORTHUMBERLAND:
# Right devotate, my lord, he has;
# Unll slaughter, to set him a bale
